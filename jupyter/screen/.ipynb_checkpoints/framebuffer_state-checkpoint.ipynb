# %% [markdown]
# ## Framebuffer State

# %%
# !poetry add Pillow
# !poetry add pyscreenshot

# %%
import pyscreenshot
from PIL import Image

# %%
current_screen_state1 = pyscreenshot.grab()

# %%
current_screen_state2 = pyscreenshot.grab()

# %%
state1_data = current_screen_state1.getdata()

# %%
state2_data = current_screen_state2.getdata()

# %%
diff = ImageChops.difference(current_screen_state1, current_screen_state2)
# Out:
# False

# %%
diff.show()

# %% [markdown]
# ## Some Tests

# %%
rgba_colors = list(current_screen_state.getdata())

# %%
rgba_colors
# Out:
# [(19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
#  (19, 19, 19, 255),
# ...

# %%
image_object.convert_matrix??
# Out:
# Docstring: <no docstring>
# Type:      builtin_function_or_method

# %%
image_object2 = current_screen_state.getdata()

# %%
diff_object = image_object1.chop_difference(image_object2)

# %%
image_object2

# %%
diff_object

# %%
width, height = len(list(diff_object)), 1
image = Image.new("RGBA", (width, height))

# %%
for x, rgba in enumerate(list(diff_object)):
    image.putpixel((x, 0), rgba)

# %%
image.save("test.png")

# %%
diff_object.mode
# Out:
# 'RGBA'

# %%
pixels_2d = [pixels[i:i+width] for i in range(0, len(list(diff_object)), width)]

# %%
diff_object.size
# Out:
# (1920, 1200)

# %%
width, height = diff_object.size
print(width)
# Reshape the pixel values to a 2D list
pixels_2d = [list(diff_object)[i: i + width] for i in range(0, len(list(diff_object)), width)]
# Out:
# 1920
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[67], line 4
#       3 # Reshape the pixel values to a 2D list
# ----> 4 pixels_2d = [list(diff_object)[i: i + width] for i in range(0, len(list(diff_object)), width)]
#
# Cell In[67], line 4, in <listcomp>(.0)
#       3 # Reshape the pixel values to a 2D list
# ----> 4 pixels_2d = [list(diff_object)[i: i + width] for i in range(0, len(list(diff_object)), width)]
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/BoostUpProjects/merlin/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3574, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3572 except:
#    3573     if result is not None:
# ...

# %%
from PIL import Image

# %%
Image.core.
